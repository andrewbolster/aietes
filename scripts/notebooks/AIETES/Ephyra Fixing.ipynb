# %%
results_path = "/home/bolster/src/aietes/results/Malicious Behaviour Trust Comparison-2016-03-22-00-33-26"

# %%
import os
os.chdir(results_path)
from bounos.DataPackage import DataPackage
# %matplotlib inline

# %%
dp = DataPackage(source="Behaviour(Waypoint)/Behaviour(Waypoint).aietes.npz")

# %%
dp.plot_axes_views(

# %%
dp.waypoints
# Out:
# array([[array([ 333.333,  333.333,  333.333]), 50],
#        [array([ 666.667,  333.333,  333.333]), 50],
#        [array([ 666.667,  666.667,  333.333]), 50],
#        [array([ 333.333,  666.667,  333.333]), 50],
#        [array([ 333.333,  333.333,  666.667]), 50],
#        [array([ 666.667,  333.333,  666.667]), 50],
#        [array([ 666.667,  666.667,  666.667]), 50],
#        [array([ 333.333,  666.667,  666.667]), 50]], dtype=object)
