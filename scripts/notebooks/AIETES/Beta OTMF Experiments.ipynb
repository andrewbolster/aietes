# %%
import scipy as sp
from scipy.stats import beta
import pandas as pd

ab_tups=[(1,1),(10,90),(50,50),(90,10)]

def beta_f(t):
    a,b=t
    x = np.linspace(beta.ppf(0, a, b),
                    beta.ppf(1.0, a, b),100)
    plot(beta.pdf(x,a,b))
    return x
_=map(beta_f,ab_tups)

# %%
mean, var, skew, kurt = beta.stats(1, 1, moments='mvsk')

# %%
mean, var, skew, kurt
# Out:
# (array(0.5), array(0.08333333333333333), array(0.0), array(-1.2))
