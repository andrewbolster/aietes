# %%
import pandas as pd
import re
import seaborn as sns
import aietes
reload(aietes)

# Make up a datapackage and hope for the best
sim = aietes.Simulation(title="test",
                        config_file=aietes.Tools.get_config_file('combined.conf'),
                        progress_display=False)
sim.prepare(sim_time=1250)
sim.simulate()
dp = sim.generate_datapackage()
# Out:
# 0.00     INFO   test:creating instance from /home/bolster/src/aietes/src/aietes/configs/combined.conf (129)
# INFO:test:creating instance from /home/bolster/src/aietes/src/aietes/configs/combined.conf
# CRITICAL:root:Invalid Config; Dying: Node Generation failed: Zero nodes with config {'Node': {'count': 0, 'Nodes': {}, 'naming_convention': ['Alpha', 'Beta', 'Gamma', 'Delta', 'Epsilon', 'Zeta', 'Eta', 'Theta', 'Iota', 'Kappa', 'Lambda', 'Mu', 'Nu', 'Xi', 'Omicron', 'Pi', 'Rho', 'Sigma', 'Tau', 'Upsilon', 'Phi', 'Chi', 'Psi', 'Omega']}, 'Environment': {'shape': [500, 500, 500], 'resolution': 1, 'base_depth': -1000}, 'Simulation': {'sim_duration': 1250, 'channel_event_name': 'AcousticEvent', 'sim_interval': 1.0}, 'log_level': 'info', 'Fleets': {'fleet': 'Fleet'}}
# Warning: IOStream has no fileno.
# ---------------------------------------------------------------------------
# ConfigError                               Traceback (most recent call last)
# <ipython-input-1-9bbd7297a0db> in <module>()
#       9                         config_file=aietes.Tools.get_config_file('combined.conf'),
#      10                         progress_display=False)
# ---> 11 sim.prepare(sim_time=1250)
#      12 sim.simulate()
#      13 dp = sim.generate_datapackage()
#
# /home/bolster/src/aietes/src/aietes/__init__.pyc in prepare(self, waits, *args, **kwargs)
#     178
#     179         self.environment = self.configure_environment(self.config.Environment)
# --> 180         self.nodes = self.configure_nodes()
#     181
#     182         #
#
# /home/bolster/src/aietes/src/aietes/__init__.pyc in configure_nodes(self)
#     585         else:
#     586             raise ConfigError(
# --> 587                 "Node Generation failed: Zero nodes with config {0!s}".format(str(self.config)))
#     588
#     589     def generate_a_node(self, node_name, node_config):
#
# ConfigError: "Node Generation failed: Zero nodes with config {'Node': {'count': 0, 'Nodes': {}, 'naming_convention': ['Alpha', 'Beta', 'Gamma', 'Delta', 'Epsilon', 'Zeta', 'Eta', 'Theta', 'Iota', 'Kappa', 'Lambda', 'Mu', 'Nu', 'Xi', 'Omicron', 'Pi', 'Rho', 'Sigma', 'Tau', 'Upsilon', 'Phi', 'Chi', 'Psi', 'Omega']}, 'Environment': {'shape': [500, 500, 500], 'resolution': 1, 'base_depth': -1000}, 'Simulation': {'sim_duration': 1250, 'channel_event_name': 'AcousticEvent', 'sim_interval': 1.0}, 'log_level': 'info', 'Fleets': {'fleet': 'Fleet'}}"

# %%
import aietes.Applications as Apps
reload(Apps)
b=Apps.BehaviourTrust.physical_metrics_from_position_log(dp.p)

# %%
_ = np.seterr(invalid='ignore') # Pandas PITA Nan printing

dp.get_global_trust_logs()

# %%
f=sim.fleets[0]
a=f.nodes[0]
# Out:
# < Instance of Node, id 140060756295888:
# 	.highest_attained_speed=1.2525442802
# 	.pos_log=[[ 234.     234.007  234.02  ...,  246.796  246.087  245.392]
#  [ 234.     234.021  234.063 ...,   81.697   81.604   81.521]
#  [ 253.     253.     253.    ...,  253.     253.     253.   ]]
# 	.internalEvent=< Instance of SimEvent, id 140060756297680:
# 		.name=Epsilon
# 		.waits=[]
# 		.queues=[]
# 		.signalparam=None
# 		.occurred=False
# 		.sim=<SimPy.SimulationStep.SimulationStep object at 0x7f62700eced0>
# 	>
# 	.interruptLeft=1
# 	.app=< Instance of CombinedBadMouthingPowerControl, id 140060756297360:
# 		.pos_log=[]
# 		.period=40.0
# 		.result_packet_dl={'Alpha': [], 'Beta': [], 'Zeta': [], 'Gamma': [], 'Delta': []}
# 		.forced_nodes=['Epsilon', 'Beta', 'Delta', 'Alpha', 'Zeta', 'Gamma']
# 		.sent_log=[]
# 		.eventsFired=[]
# 		.packet_receivers=[<bound method CombinedBadMouthingPowerControl.update_counters of < Instance of CombinedBadMouthingPowerControl, id 140060756297360:
# 			.pos_log=[]
# 			.period=40.0
# 			.result_packet_dl={'Alpha': [], 'Beta': [], 'Zeta': [], 'Gamma': [], 'Delta': []}
# 			.forced_nodes=['Epsilon', 'Beta', 'Delta', 'Alpha', 'Zeta', 'Gamma']
# 			.sent_log=[]
# 			.eventsFired=[]
# 			.packet_receivers=[...]
# 			.stats={'packets_received': 0, 'packets_sent': 0, 'packets_time': 0, 'packets_hops': 0, 'packets_dhops': 0}
# 			.trust_assessments={'Epsilon': [Series([], dtype: float64), INDD     159.880394
# INHD       1.004354
# Speed      1.084985
# dtype: float64, INDD     175.943911
# INHD       1.132493
# Speed      1.219149
# dtype: float64], 'Beta': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            183.085749
# INHD              1.023671
# Speed             1.134725
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            188.791362
# INHD              0.726689
# Speed             0.845038
# dtype: float64], 'Delta': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            151.709957
# INHD              0.941069
# Speed             1.159259
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            171.670818
# INHD              1.088655
# Speed             1.198692
# dtype: float64], 'Alpha': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            157.800202
# INHD              1.039287
# Speed             1.174325
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            187.438057
# INHD              1.163296
# Speed             1.230607
# dtype: float64], 'Zeta': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            230.695376
# INHD              0.962653
# Speed             0.887620
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            166.295941
# INHD              0.878500
# Speed             0.977327
# dtype: float64], 'Gamma': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            167.557152
# INHD              1.230298
# Speed             1.188355
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            204.882827
# INHD              1.203963
# Speed             1.108490
# dtype: float64]}
# 			.last_trust_assessment=None
# 			.trust_accessories={'queue_length': [0, 0], 'collisions': [0, 0]}
# 			.tick_assessors=[<bound method CombinedBadMouthingPowerControl.rx_trust_metrics of  ... >, <bound method CombinedBadMouthingPowerControl.tx_trust_metrics of  ... >, <bound method CombinedBadMouthingPowerControl.physical_metrics of  ... >]
# 			.packet_rate=0.025
# 			.logger=<logging.Logger object at 0x7f626fa046d0>
# 			.config={'protocol': 'CombinedBadMouthingPowerControl', 'median': False, 'packet_count': 0, 'packet_rate': 0.025, 'packet_length': '9600', 'distribution': [1]}
# 			.layercake=<aietes.Layercake.Layercake object at 0x7f626fa04250>
# 			.sim=<SimPy.SimulationStep.SimulationStep object at 0x7f62700eced0>
# 			.node= ...
# 			.sim_duration=1250
# 			.sent_counter=Counter()
# 			.test_packet_counter=Counter({'Alpha': 0, 'Beta': 0, 'Zeta': 0, 'Gamma': 0, 'Delta': 0})
# 			.last_accessed_rx_packet=-1
# 			.received_counter=Counter()
# 			.name=CombinedBadMouthingPowerControl(Epsilon)
# 			.received_log=[]
# 			.total_counter=Counter({'Alpha': 0, 'Beta': 0, 'Zeta': 0, 'Gamma': 0, 'Delta': 0})
# 			.current_target=None
# 			.use_median=False
# 		>>, <bound method CombinedBadMouthingPowerControl.update_log_from_packet of < Instance of CombinedBadMouthingPowerControl, id 140060756297360:
# 			.pos_log=[]
# 			.period=40.0
# 			.result_packet_dl={'Alpha': [], 'Beta': [], 'Zeta': [], 'Gamma': [], 'Delta': []}
# 			.forced_nodes=['Epsilon', 'Beta', 'Delta', 'Alpha', 'Zeta', 'Gamma']
# 			.sent_log=[]
# 			.eventsFired=[]
# 			.packet_receivers=[...]
# 			.stats={'packets_received': 0, 'packets_sent': 0, 'packets_time': 0, 'packets_hops': 0, 'packets_dhops': 0}
# 			.trust_assessments={'Epsilon': [Series([], dtype: float64), INDD     159.880394
# INHD       1.004354
# Speed      1.084985
# dtype: float64, INDD     175.943911
# INHD       1.132493
# Speed      1.219149
# dtype: float64], 'Beta': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            183.085749
# INHD              1.023671
# Speed             1.134725
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            188.791362
# INHD              0.726689
# Speed             0.845038
# dtype: float64], 'Delta': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            151.709957
# INHD              0.941069
# Speed             1.159259
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            171.670818
# INHD              1.088655
# Speed             1.198692
# dtype: float64], 'Alpha': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            157.800202
# INHD              1.039287
# Speed             1.174325
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            187.438057
# INHD              1.163296
# Speed             1.230607
# dtype: float64], 'Zeta': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            230.695376
# INHD              0.962653
# Speed             0.887620
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            166.295941
# INHD              0.878500
# Speed             0.977327
# dtype: float64], 'Gamma': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            167.557152
# INHD              1.230298
# Speed             1.188355
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            204.882827
# INHD              1.203963
# Speed             1.108490
# dtype: float64]}
# 			.last_trust_assessment=None
# 			.trust_accessories={'queue_length': [0, 0], 'collisions': [0, 0]}
# 			.tick_assessors=[<bound method CombinedBadMouthingPowerControl.rx_trust_metrics of  ... >, <bound method CombinedBadMouthingPowerControl.tx_trust_metrics of  ... >, <bound method CombinedBadMouthingPowerControl.physical_metrics of  ... >]
# 			.packet_rate=0.025
# 			.logger=<logging.Logger object at 0x7f626fa046d0>
# 			.config={'protocol': 'CombinedBadMouthingPowerControl', 'median': False, 'packet_count': 0, 'packet_rate': 0.025, 'packet_length': '9600', 'distribution': [1]}
# 			.layercake=<aietes.Layercake.Layercake object at 0x7f626fa04250>
# 			.sim=<SimPy.SimulationStep.SimulationStep object at 0x7f62700eced0>
# 			.node= ...
# 			.sim_duration=1250
# 			.sent_counter=Counter()
# 			.test_packet_counter=Counter({'Alpha': 0, 'Beta': 0, 'Zeta': 0, 'Gamma': 0, 'Delta': 0})
# 			.last_accessed_rx_packet=-1
# 			.received_counter=Counter()
# 			.name=CombinedBadMouthingPowerControl(Epsilon)
# 			.received_log=[]
# 			.total_counter=Counter({'Alpha': 0, 'Beta': 0, 'Zeta': 0, 'Gamma': 0, 'Delta': 0})
# 			.current_target=None
# 			.use_median=False
# 		>>]
# 		.stats={'packets_received': 0, 'packets_sent': 0, 'packets_time': 0, 'packets_hops': 0, 'packets_dhops': 0}
# 		.trust_assessments={'Epsilon': [Series([], dtype: float64), INDD     159.880394
# INHD       1.004354
# Speed      1.084985
# dtype: float64, INDD     175.943911
# INHD       1.132493
# Speed      1.219149
# dtype: float64], 'Beta': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            183.085749
# INHD              1.023671
# Speed             1.134725
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            188.791362
# INHD              0.726689
# Speed             0.845038
# dtype: float64], 'Delta': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            151.709957
# INHD              0.941069
# Speed             1.159259
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            171.670818
# INHD              1.088655
# Speed             1.198692
# dtype: float64], 'Alpha': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            157.800202
# INHD              1.039287
# Speed             1.174325
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            187.438057
# INHD              1.163296
# Speed             1.230607
# dtype: float64], 'Zeta': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            230.695376
# INHD              0.962653
# Speed             0.887620
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            166.295941
# INHD              0.878500
# Speed             0.977327
# dtype: float64], 'Gamma': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            167.557152
# INHD              1.230298
# Speed             1.188355
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            204.882827
# INHD              1.203963
# Speed             1.108490
# dtype: float64]}
# 		.last_trust_assessment=None
# 		.trust_accessories={'queue_length': [0, 0], 'collisions': [0, 0]}
# 		.tick_assessors=[<bound method CombinedBadMouthingPowerControl.rx_trust_metrics of < Instance of CombinedBadMouthingPowerControl, id 140060756297360:
# 			.pos_log=[]
# 			.period=40.0
# 			.result_packet_dl={'Alpha': [], 'Beta': [], 'Zeta': [], 'Gamma': [], 'Delta': []}
# 			.forced_nodes=['Epsilon', 'Beta', 'Delta', 'Alpha', 'Zeta', 'Gamma']
# 			.sent_log=[]
# 			.eventsFired=[]
# 			.packet_receivers=[<bound method CombinedBadMouthingPowerControl.update_counters of  ... >, <bound method CombinedBadMouthingPowerControl.update_log_from_packet of  ... >]
# 			.stats={'packets_received': 0, 'packets_sent': 0, 'packets_time': 0, 'packets_hops': 0, 'packets_dhops': 0}
# 			.trust_assessments={'Epsilon': [Series([], dtype: float64), INDD     159.880394
# INHD       1.004354
# Speed      1.084985
# dtype: float64, INDD     175.943911
# INHD       1.132493
# Speed      1.219149
# dtype: float64], 'Beta': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            183.085749
# INHD              1.023671
# Speed             1.134725
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            188.791362
# INHD              0.726689
# Speed             0.845038
# dtype: float64], 'Delta': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            151.709957
# INHD              0.941069
# Speed             1.159259
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            171.670818
# INHD              1.088655
# Speed             1.198692
# dtype: float64], 'Alpha': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            157.800202
# INHD              1.039287
# Speed             1.174325
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            187.438057
# INHD              1.163296
# Speed             1.230607
# dtype: float64], 'Zeta': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            230.695376
# INHD              0.962653
# Speed             0.887620
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            166.295941
# INHD              0.878500
# Speed             0.977327
# dtype: float64], 'Gamma': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            167.557152
# INHD              1.230298
# Speed             1.188355
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            204.882827
# INHD              1.203963
# Speed             1.108490
# dtype: float64]}
# 			.last_trust_assessment=None
# 			.trust_accessories={'queue_length': [0, 0], 'collisions': [0, 0]}
# 			.tick_assessors=[...]
# 			.packet_rate=0.025
# 			.logger=<logging.Logger object at 0x7f626fa046d0>
# 			.config={'protocol': 'CombinedBadMouthingPowerControl', 'median': False, 'packet_count': 0, 'packet_rate': 0.025, 'packet_length': '9600', 'distribution': [1]}
# 			.layercake=<aietes.Layercake.Layercake object at 0x7f626fa04250>
# 			.sim=<SimPy.SimulationStep.SimulationStep object at 0x7f62700eced0>
# 			.node= ...
# 			.sim_duration=1250
# 			.sent_counter=Counter()
# 			.test_packet_counter=Counter({'Alpha': 0, 'Beta': 0, 'Zeta': 0, 'Gamma': 0, 'Delta': 0})
# 			.last_accessed_rx_packet=-1
# 			.received_counter=Counter()
# 			.name=CombinedBadMouthingPowerControl(Epsilon)
# 			.received_log=[]
# 			.total_counter=Counter({'Alpha': 0, 'Beta': 0, 'Zeta': 0, 'Gamma': 0, 'Delta': 0})
# 			.current_target=None
# 			.use_median=False
# 		>>, <bound method CombinedBadMouthingPowerControl.tx_trust_metrics of < Instance of CombinedBadMouthingPowerControl, id 140060756297360:
# 			.pos_log=[]
# 			.period=40.0
# 			.result_packet_dl={'Alpha': [], 'Beta': [], 'Zeta': [], 'Gamma': [], 'Delta': []}
# 			.forced_nodes=['Epsilon', 'Beta', 'Delta', 'Alpha', 'Zeta', 'Gamma']
# 			.sent_log=[]
# 			.eventsFired=[]
# 			.packet_receivers=[<bound method CombinedBadMouthingPowerControl.update_counters of  ... >, <bound method CombinedBadMouthingPowerControl.update_log_from_packet of  ... >]
# 			.stats={'packets_received': 0, 'packets_sent': 0, 'packets_time': 0, 'packets_hops': 0, 'packets_dhops': 0}
# 			.trust_assessments={'Epsilon': [Series([], dtype: float64), INDD     159.880394
# INHD       1.004354
# Speed      1.084985
# dtype: float64, INDD     175.943911
# INHD       1.132493
# Speed      1.219149
# dtype: float64], 'Beta': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            183.085749
# INHD              1.023671
# Speed             1.134725
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            188.791362
# INHD              0.726689
# Speed             0.845038
# dtype: float64], 'Delta': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            151.709957
# INHD              0.941069
# Speed             1.159259
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            171.670818
# INHD              1.088655
# Speed             1.198692
# dtype: float64], 'Alpha': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            157.800202
# INHD              1.039287
# Speed             1.174325
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            187.438057
# INHD              1.163296
# Speed             1.230607
# dtype: float64], 'Zeta': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            230.695376
# INHD              0.962653
# Speed             0.887620
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            166.295941
# INHD              0.878500
# Speed             0.977327
# dtype: float64], 'Gamma': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            167.557152
# INHD              1.230298
# Speed             1.188355
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            204.882827
# INHD              1.203963
# Speed             1.108490
# dtype: float64]}
# 			.last_trust_assessment=None
# 			.trust_accessories={'queue_length': [0, 0], 'collisions': [0, 0]}
# 			.tick_assessors=[...]
# 			.packet_rate=0.025
# 			.logger=<logging.Logger object at 0x7f626fa046d0>
# 			.config={'protocol': 'CombinedBadMouthingPowerControl', 'median': False, 'packet_count': 0, 'packet_rate': 0.025, 'packet_length': '9600', 'distribution': [1]}
# 			.layercake=<aietes.Layercake.Layercake object at 0x7f626fa04250>
# 			.sim=<SimPy.SimulationStep.SimulationStep object at 0x7f62700eced0>
# 			.node= ...
# 			.sim_duration=1250
# 			.sent_counter=Counter()
# 			.test_packet_counter=Counter({'Alpha': 0, 'Beta': 0, 'Zeta': 0, 'Gamma': 0, 'Delta': 0})
# 			.last_accessed_rx_packet=-1
# 			.received_counter=Counter()
# 			.name=CombinedBadMouthingPowerControl(Epsilon)
# 			.received_log=[]
# 			.total_counter=Counter({'Alpha': 0, 'Beta': 0, 'Zeta': 0, 'Gamma': 0, 'Delta': 0})
# 			.current_target=None
# 			.use_median=False
# 		>>, <bound method CombinedBadMouthingPowerControl.physical_metrics of < Instance of CombinedBadMouthingPowerControl, id 140060756297360:
# 			.pos_log=[]
# 			.period=40.0
# 			.result_packet_dl={'Alpha': [], 'Beta': [], 'Zeta': [], 'Gamma': [], 'Delta': []}
# 			.forced_nodes=['Epsilon', 'Beta', 'Delta', 'Alpha', 'Zeta', 'Gamma']
# 			.sent_log=[]
# 			.eventsFired=[]
# 			.packet_receivers=[<bound method CombinedBadMouthingPowerControl.update_counters of  ... >, <bound method CombinedBadMouthingPowerControl.update_log_from_packet of  ... >]
# 			.stats={'packets_received': 0, 'packets_sent': 0, 'packets_time': 0, 'packets_hops': 0, 'packets_dhops': 0}
# 			.trust_assessments={'Epsilon': [Series([], dtype: float64), INDD     159.880394
# INHD       1.004354
# Speed      1.084985
# dtype: float64, INDD     175.943911
# INHD       1.132493
# Speed      1.219149
# dtype: float64], 'Beta': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            183.085749
# INHD              1.023671
# Speed             1.134725
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            188.791362
# INHD              0.726689
# Speed             0.845038
# dtype: float64], 'Delta': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            151.709957
# INHD              0.941069
# Speed             1.159259
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            171.670818
# INHD              1.088655
# Speed             1.198692
# dtype: float64], 'Alpha': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            157.800202
# INHD              1.039287
# Speed             1.174325
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            187.438057
# INHD              1.163296
# Speed             1.230607
# dtype: float64], 'Zeta': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            230.695376
# INHD              0.962653
# Speed             0.887620
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            166.295941
# INHD              0.878500
# Speed             0.977327
# dtype: float64], 'Gamma': [Series([], dtype: float64), PLR               0.000000
# TXThroughput      0.000000
# INDD            167.557152
# INHD              1.230298
# Speed             1.188355
# dtype: float64, PLR               0.000000
# TXThroughput      0.000000
# INDD            204.882827
# INHD              1.203963
# Speed             1.108490
# dtype: float64]}
# 			.last_trust_assessment=None
# 			.trust_accessories={'queue_length': [0, 0], 'collisions': [0, 0]}
# 			.tick_assessors=[...]
# 			.packet_rate=0.025
# 			.logger=<logging.Logger object at 0x7f626fa046d0>
# 			.config={'protocol': 'CombinedBadMouthingPowerControl', 'median': False, 'packet_count': 0, 'packet_rate': 0.025, 'packet_length': '9600', 'distribution': [1]}
# 			.layercake=<aietes.Layercake.Layercake object at 0x7f626fa04250>
# 			.sim=<SimPy.SimulationStep.SimulationStep object at 0x7f62700eced0>
# 			.node= ...
# 			.sim_duration=1250
# 			.sent_counter=Counter()
# 			.test_packet_counter=Counter({'Alpha': 0, 'Beta': 0, 'Zeta': 0, 'Gamma': 0, 'Delta': 0})
# 			.last_accessed_rx_packet=-1
# 			.received_counter=Counter()
# 			.name=CombinedBadMouthingPowerControl(Epsilon)
# 			.received_log=[]
# 			.total_counter=Counter({'Alpha': 0, 'Beta': 0, 'Zeta': 0, 'Gamma': 0, 'Delta': 0})
# 			.current_target=None
# 			.use_median=False
# 		>>]
# 		.packet_rate=0.025
# 		.logger=<logging.Logger object at 0x7f626fa046d0>
# 		.config={'protocol': 'CombinedBadMouthingPowerControl', 'median': False, 'packet_count': 0, 'packet_rate': 0.025, 'packet_length': '9600', 'distribution': [1]}
# 		.layercake=<aietes.Layercake.Layercake object at 0x7f626fa04250>
# 		.sim=<SimPy.SimulationStep.SimulationStep object at 0x7f62700eced0>
# 		.node=< Instance of Node, id 140060756295888:
# 			.highest_attained_speed=1.2525442802
# 			.pos_log=[[ 234.     234.007  234.02  ...,  246.796  246.087  245.392]
#  [ 234.     234.021  234.063 ...,   81.697   81.604   81.521]
#  [ 253.     253.     253.    ...,  253.     253.     253.   ]]
# 			.internalEvent= ...
# 			.interruptLeft=1
# 			.app= ...
# 			.settling_time=0
# 			.nodenum=0
# 			.max_speed=[ 1.5  1.5  1.5]
# 			.eventsFired=[]
# 			.id=5e41434e-09f0-406e-ae7f-a7185a4ce5c9
# 			.achievements_log=[[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [] ...
# 			.max_turn=[[4.5, 4.5, 4.5], [4.5, 4.5, 4.5], [4.5, 4.5, 4.5]]
# 			.interruptCause=None
# 			.contributions_log=[{'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': ar ...
# 			.logger=<logging.Logger object at 0x7f626fa041d0>
# 			.config={'max_turn': [4.5, 4.5, 4.5], 'beacon_rate': 15, 'bev': 'Null', 'position_generation': 'center', 'ecea': 'Null', 'memory_model': 'global', 'app': 'Null', 'drift': 'Null', 'mac': 'CSMA4FBR', 'phy': 'PhysicalLayer', 'max_speed': [1.5], 'tof_type': 0, 'net': 'FBR', 'cruising_speed': [1.25], 'drift_noises': {}, 'drift_scales': {}, 'Behaviour': {'nearest_neighbours': 4, 'protocol': 'RandomFlatWalk', 'waypoint_factor': [0.05], 'neighbourhood_max_rad': 100, 'waypoint_style': 'patrol_cube', 'update_rate': 1.0, 'positional_accuracy': [10.0], 'schooling_factor': [0.01], 'repulsive_factor': [0.125], 'clumping_factor': [0.125, 0.125, 0.5], 'distribution': [1], 'collision_avoidance_d': [50.0], 'neighbourhood_min_rad': 10}, 'PHY': {'max_transmit_power': 250.0, 'listen_power': -30.0, 'variable_bandwidth': False, 'range': 1500.0, 'receive_power': -30.0, 'bandwidth': 10.89, 'frequency': 20.0, 'transmit_power': 250.0, 'variable_power': True, 'bandwidth_to_bit_ratio': 2.0, 'medium_speed': 1490.0, 'var_power': {'1': 1500.0, '0': 1000.0, '3': 2500.0, '2': 2000.0}, 'threshold': {'SIR': 15.0, 'SNR': 20.0, 'LIS': 3.0}}, 'Application': {'protocol': 'CombinedBadMouthingPowerControl', 'median': False, 'packet_count': 0, 'packet_rate': 0.025, 'packet_length': '9600', 'distribution': [1]}, 'MAC': {'war_packet_length': 24, 'protocol': 'CSMA4FBR', 'deltadt': 0.0, 'rts_packet_length': 48, 'data_packet_length': 9600, 'tminper': 2.0, 'ack_packet_length': 24, 'max2resend': 10, 'deltatdata': 0.0, 'attempts': 4, 'twminper': 0.0, 'sil_packet_length': 24, 'cts_packet_length': 48}, 'Network': {'rx_cone': False, 'protocol': 'SimpleRoutingTable', 'coneAngle': 60.0}}
# 			.layercake=<aietes.Layercake.Layercake object at 0x7f626fa04250>
# 			.sim=<SimPy.SimulationStep.SimulationStep object at 0x7f62700eced0>
# 			.acceleration_force=[ 0.507  0.368  0.   ]
# 			.drifting=False
# 			.behaviour=<aietes.Behaviour.RandomFlatWalk object at 0x7f626fa04750>
# 			.debug=False
# 			.velocity=[-0.695 -0.083  0.   ]
# 			.on_mission=True
# 			.position=[ 245.392   81.521  253.   ]
# 			.vec_log=[[ 0.     0.007  0.013 ..., -0.722 -0.708 -0.695]
#  [ 0.     0.021  0.042 ..., -0.103 -0.093 -0.083]
#  [ 0.     0.     0.    ...,  0.     0.     0.   ]]
# 			.wallCheckDisabled=False
# 			.name=Epsilon
# 			.ecea=False
# 			.simulation=<aietes.Simulation object at 0x7f626fa98dd0>
# 			.mass=37
# 			.fleet= ...
# 			.cruising_speed=[ 1.25  1.25  1.25]
# 		>
# 		.sim_duration=1250
# 		.sent_counter=Counter()
# 		.test_packet_counter=Counter({'Alpha': 0, 'Beta': 0, 'Zeta': 0, 'Gamma': 0, 'Delta': 0})
# 		.last_accessed_rx_packet=-1
# 		.received_counter=Counter()
# 		.name=CombinedBadMouthingPowerControl(Epsilon)
# 		.received_log=[]
# 		.total_counter=Counter({'Alpha': 0, 'Beta': 0, 'Zeta': 0, 'Gamma': 0, 'Delta': 0})
# 		.current_target=None
# 		.use_median=False
# 	>
# 	.settling_time=0
# 	.nodenum=0
# 	.max_speed=[ 1.5  1.5  1.5]
# 	.eventsFired=[]
# 	.id=5e41434e-09f0-406e-ae7f-a7185a4ce5c9
# 	.achievements_log=[[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [],  ...
# 	.max_turn=[[4.5, 4.5, 4.5], [4.5, 4.5, 4.5], [4.5, 4.5, 4.5]]
# 	.interruptCause=None
# 	.contributions_log=[{'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.245,  0.776,  0.   ])}, {'avoid_wall': arra ...
# 	.logger=<logging.Logger object at 0x7f626fa041d0>
# 	.config={'max_turn': [4.5, 4.5, 4.5], 'beacon_rate': 15, 'bev': 'Null', 'position_generation': 'center', 'ecea': 'Null', 'memory_model': 'global', 'app': 'Null', 'drift': 'Null', 'mac': 'CSMA4FBR', 'phy': 'PhysicalLayer', 'max_speed': [1.5], 'tof_type': 0, 'net': 'FBR', 'cruising_speed': [1.25], 'drift_noises': {}, 'drift_scales': {}, 'Behaviour': {'nearest_neighbours': 4, 'protocol': 'RandomFlatWalk', 'waypoint_factor': [0.05], 'neighbourhood_max_rad': 100, 'waypoint_style': 'patrol_cube', 'update_rate': 1.0, 'positional_accuracy': [10.0], 'schooling_factor': [0.01], 'repulsive_factor': [0.125], 'clumping_factor': [0.125, 0.125, 0.5], 'distribution': [1], 'collision_avoidance_d': [50.0], 'neighbourhood_min_rad': 10}, 'PHY': {'max_transmit_power': 250.0, 'listen_power': -30.0, 'variable_bandwidth': False, 'range': 1500.0, 'receive_power': -30.0, 'bandwidth': 10.89, 'frequency': 20.0, 'transmit_power': 250.0, 'variable_power': True, 'bandwidth_to_bit_ratio': 2.0, 'medium_speed': 1490.0, 'var_power': {'1': 1500.0, '0': 1000.0, '3': 2500.0, '2': 2000.0}, 'threshold': {'SIR': 15.0, 'SNR': 20.0, 'LIS': 3.0}}, 'Application': {'protocol': 'CombinedBadMouthingPowerControl', 'median': False, 'packet_count': 0, 'packet_rate': 0.025, 'packet_length': '9600', 'distribution': [1]}, 'MAC': {'war_packet_length': 24, 'protocol': 'CSMA4FBR', 'deltadt': 0.0, 'rts_packet_length': 48, 'data_packet_length': 9600, 'tminper': 2.0, 'ack_packet_length': 24, 'max2resend': 10, 'deltatdata': 0.0, 'attempts': 4, 'twminper': 0.0, 'sil_packet_length': 24, 'cts_packet_length': 48}, 'Network': {'rx_cone': False, 'protocol': 'SimpleRoutingTable', 'coneAngle': 60.0}}
# 	.layercake=<aietes.Layercake.Layercake object at 0x7f626fa04250>
# 	.sim=<SimPy.SimulationStep.SimulationStep object at 0x7f62700eced0>
# 	.acceleration_force=[ 0.507  0.368  0.   ]
# 	.drifting=False
# 	.behaviour=<aietes.Behaviour.RandomFlatWalk object at 0x7f626fa04750>
# 	.debug=False
# 	.velocity=[-0.695 -0.083  0.   ]
# 	.on_mission=True
# 	.position=[ 245.392   81.521  253.   ]
# 	.vec_log=[[ 0.     0.007  0.013 ..., -0.722 -0.708 -0.695]
#  [ 0.     0.021  0.042 ..., -0.103 -0.093 -0.083]
#  [ 0.     0.     0.    ...,  0.     0.     0.   ]]
# 	.wallCheckDisabled=False
# 	.name=Epsilon
# 	.ecea=False
# 	.simulation=<aietes.Simulation object at 0x7f626fa98dd0>
# 	.mass=37
# 	.fleet=< Instance of Fleet, id 140060756295760:
# 		.name=Fleet
# 		.shared_map=<aietes.Environment.Environment object at 0x7f626f9c3fd0>
# 		.waiting=False
# 		.nodes=[< Instance of Node, id 140060756295888:
# 			.highest_attained_speed=1.2525442802
# 			.pos_log=[[ 234.     234.007  234.02  ...,  246.796  246.087  245.392]
#  [ 234.     234.021  234.063 ...,   81.697   81.604   81.521]
#  [ 253.     253.     253.    ...,  253.     253.     253.   ]]
# 			.internalEvent= ...
# 			.interruptLeft=1
# 			.app= ...
# 			.settling_time=0
# 			.nodenum=0
# 			.max_speed=[ 1.5  1.5  1.5]
# 			.eventsFired=[]
# 			.id=5e41434e-09f0-406e-ae7f-a7185a4ce5c9
# 			.achievements_log=[[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [] ...
# 			.max_turn=[[4.5, 4.5, 4.5], [4.5, 4.5, 4.5], [4.5, 4.5, 4.5]]
# 			.interruptCause=None
# ...
# 			.logger=<logging.Logger object at 0x7f626faabad0>
# 			.config={'max_turn': [4.5, 4.5, 4.5], 'beacon_rate': 15, 'bev': 'Null', 'position_generation': 'center', 'ecea': 'Null', 'memory_model': 'global', 'app': 'Null', 'drift': 'Null', 'mac': 'CSMA4FBR', 'phy': 'PhysicalLayer', 'max_speed': [1.5], 'tof_type': 0, 'net': 'FBR', 'cruising_speed': [1.25], 'drift_noises': {}, 'drift_scales': {}, 'Behaviour': {'nearest_neighbours': 4, 'protocol': 'RandomFlatWalk', 'waypoint_factor': [0.05], 'neighbourhood_max_rad': 100, 'waypoint_style': 'patrol_cube', 'update_rate': 1.0, 'positional_accuracy': [10.0], 'schooling_factor': [0.01], 'repulsive_factor': [0.125], 'clumping_factor': [0.125, 0.125, 0.5], 'distribution': [1], 'collision_avoidance_d': [50.0], 'neighbourhood_min_rad': 10}, 'PHY': {'max_transmit_power': 250.0, 'listen_power': -30.0, 'variable_bandwidth': False, 'range': 1500.0, 'receive_power': -30.0, 'bandwidth': 10.89, 'frequency': 20.0, 'transmit_power': 250.0, 'variable_power': True, 'bandwidth_to_bit_ratio': 2.0, 'medium_speed': 1490.0, 'var_power': {'1': 1500.0, '0': 1000.0, '3': 2500.0, '2': 2000.0}, 'threshold': {'SIR': 15.0, 'SNR': 20.0, 'LIS': 3.0}}, 'Application': {'protocol': 'CombinedBadMouthingPowerControl', 'median': False, 'packet_count': 0, 'packet_rate': 0.025, 'packet_length': '9600', 'distribution': [1]}, 'MAC': {'war_packet_length': 24, 'protocol': 'CSMA4FBR', 'deltadt': 0.0, 'rts_packet_length': 48, 'data_packet_length': 9600, 'tminper': 2.0, 'ack_packet_length': 24, 'max2resend': 10, 'deltatdata': 0.0, 'attempts': 4, 'twminper': 0.0, 'sil_packet_length': 24, 'cts_packet_length': 48}, 'Network': {'rx_cone': False, 'protocol': 'SimpleRoutingTable', 'coneAngle': 60.0}}
# 			.layercake=<aietes.Layercake.Layercake object at 0x7f626faabc50>
# 			.sim=<SimPy.SimulationStep.SimulationStep object at 0x7f62700eced0>
# 			.acceleration_force=[-0.114 -0.994  0.   ]
# 			.drifting=False
# 			.behaviour=<aietes.Behaviour.RandomFlatWalk object at 0x7f626f9c3790>
# 			.debug=False
# 			.velocity=[-0.558 -1.119  0.   ]
# 			.on_mission=True
# 			.position=[ 396.386  445.782  257.   ]
# 			.vec_log=[[ 0.    -0.011 -0.023 ..., -0.559 -0.562 -0.558]
#  [ 0.     0.023  0.047 ..., -1.08  -1.107 -1.119]
#  [ 0.     0.     0.    ...,  0.     0.     0.   ]]
# 			.wallCheckDisabled=False
# 			.name=Zeta
# 			.ecea=False
# 			.simulation=<aietes.Simulation object at 0x7f626fa98dd0>
# 			.mass=37
# 			.fleet= ...
# 			.cruising_speed=[ 1.25  1.25  1.25]
# 		>, < Instance of Node, id 140060756031632:
# 			.highest_attained_speed=1.2507724072
# 			.pos_log=[[ 202.     202.017  202.05  ...,  134.34   134.174  134.005]
#  [ 278.     277.979  277.937 ...,  424.474  425.713  426.951]
#  [ 243.     243.     243.    ...,  243.     243.     243.   ]]
# 			.internalEvent= ...
# 			.interruptLeft=1
# 			.app= ...
# 			.settling_time=0
# 			.nodenum=5
# 			.max_speed=[ 1.5  1.5  1.5]
# 			.eventsFired=[]
# 			.id=8035714a-a4d0-4617-8b6c-658443f32121
# 			.achievements_log=[[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [] ...
# 			.max_turn=[[4.5, 4.5, 4.5], [4.5, 4.5, 4.5], [4.5, 4.5, 4.5]]
# 			.interruptCause=None
# 			.contributions_log=[{'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': array([ 0.,  0.,  0.]), 'random_walk': array([ 0.615, -0.776,  0.   ])}, {'avoid_wall': ar ...
# 			.logger=<logging.Logger object at 0x7f626f9c3950>
# 			.config={'max_turn': [4.5, 4.5, 4.5], 'beacon_rate': 15, 'bev': 'Null', 'position_generation': 'center', 'ecea': 'Null', 'memory_model': 'global', 'app': 'Null', 'drift': 'Null', 'mac': 'CSMA4FBR', 'phy': 'PhysicalLayer', 'max_speed': [1.5], 'tof_type': 0, 'net': 'FBR', 'cruising_speed': [1.25], 'drift_noises': {}, 'drift_scales': {}, 'Behaviour': {'nearest_neighbours': 4, 'protocol': 'RandomFlatWalk', 'waypoint_factor': [0.05], 'neighbourhood_max_rad': 100, 'waypoint_style': 'patrol_cube', 'update_rate': 1.0, 'positional_accuracy': [10.0], 'schooling_factor': [0.01], 'repulsive_factor': [0.125], 'clumping_factor': [0.125, 0.125, 0.5], 'distribution': [1], 'collision_avoidance_d': [50.0], 'neighbourhood_min_rad': 10}, 'PHY': {'max_transmit_power': 250.0, 'listen_power': -30.0, 'variable_bandwidth': False, 'range': 1500.0, 'receive_power': -30.0, 'bandwidth': 10.89, 'frequency': 20.0, 'transmit_power': 250.0, 'variable_power': True, 'bandwidth_to_bit_ratio': 2.0, 'medium_speed': 1490.0, 'var_power': {'1': 1500.0, '0': 1000.0, '3': 2500.0, '2': 2000.0}, 'threshold': {'SIR': 15.0, 'SNR': 20.0, 'LIS': 3.0}}, 'Application': {'protocol': 'CombinedBadMouthingPowerControl', 'median': False, 'packet_count': 0, 'packet_rate': 0.025, 'packet_length': '9600', 'distribution': [1]}, 'MAC': {'war_packet_length': 24, 'protocol': 'CSMA4FBR', 'deltadt': 0.0, 'rts_packet_length': 48, 'data_packet_length': 9600, 'tminper': 2.0, 'ack_packet_length': 24, 'max2resend': 10, 'deltatdata': 0.0, 'attempts': 4, 'twminper': 0.0, 'sil_packet_length': 24, 'cts_packet_length': 48}, 'Network': {'rx_cone': False, 'protocol': 'SimpleRoutingTable', 'coneAngle': 60.0}}
# 			.layercake=<aietes.Layercake.Layercake object at 0x7f626f9c39d0>
# 			.sim=<SimPy.SimulationStep.SimulationStep object at 0x7f62700eced0>
# 			.acceleration_force=[-0.157  0.411  0.   ]
# 			.drifting=False
# 			.behaviour=<aietes.Behaviour.RandomFlatWalk object at 0x7f626f9c3ed0>
# 			.debug=False
# 			.velocity=[-0.169  1.239  0.   ]
# 			.on_mission=True
# 			.position=[ 134.005  426.951  243.   ]
# 			.vec_log=[[ 0.     0.017  0.033 ..., -0.164 -0.166 -0.169]
#  [ 0.    -0.021 -0.042 ...,  1.239  1.239  1.239]
#  [ 0.     0.     0.    ...,  0.     0.     0.   ]]
# 			.wallCheckDisabled=False
# 			.name=Gamma
# 			.ecea=False
# 			.simulation=<aietes.Simulation object at 0x7f626fa98dd0>
# 			.mass=37
# 			.fleet= ...
# 			.cruising_speed=[ 1.25  1.25  1.25]
# 		>]
# 		.simulation=<aietes.Simulation object at 0x7f626fa98dd0>
# 		.environment=<aietes.Environment.Environment object at 0x7f626faab710>
# 		.cond=<function all_nodes_passive at 0x7f627061e230>
# 		.logger=<logging.Logger object at 0x7f626f9c3f90>
# 		.eventsFired=[]
# 		.sim=<SimPy.SimulationStep.SimulationStep object at 0x7f62700eced0>
# 	>
# 	.cruising_speed=[ 1.25  1.25  1.25]
# >

# %%
from pprint import pprint
a.layercake.config['app']
# Out:
# 'Null'
