# %%
import pandas as pd
import re
import seaborn as sns
import aietes
reload(aietes)

# Make up a datapackage and hope for the best
sim = aietes.Simulation(title="test",
                        config_file=aietes.Tools.get_config_file('bella_all_mobile.conf'),
                        progress_display=False)
sim.prepare(sim_time=1250)
sim.simulate()
dp = sim.generate_datapackage()
# Out:
# Warning: IOStream has no fileno.
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# 0.00     INFO   test:creating instance from /home/bolster/src/aietes/src/aietes/configs/bella_all_mobile.conf (128)
# INFO:test:creating instance from /home/bolster/src/aietes/src/aietes/configs/bella_all_mobile.conf
# 0.00     INFO   test:Gave node n0 a configured initial position: ['200', '300', '300'] (600)
# INFO:test:Gave node n0 a configured initial position: ['200', '300', '300']
# 0.00     WARNING test.aietes.Node[n0].Layercake.CSMA4FBR:I think I have pending data from None but I got something from None (2080)
# WARNING:test.aietes.Node[n0].Layercake.CSMA4FBR:I think I have pending data from None but I got something from None
# 0.00     INFO   test:Gave node n1 a configured initial position: ['300', '300', '300'] (600)
# INFO:test:Gave node n1 a configured initial position: ['300', '300', '300']
# 0.00     WARNING test.aietes.Node[n1].Layercake.CSMA4FBR:I think I have pending data from None but I got something from None (2080)
# WARNING:test.aietes.Node[n1].Layercake.CSMA4FBR:I think I have pending data from None but I got something from None
# 0.00     INFO   test:Gave node n2 a configured initial position: ['250', '350', '300'] (600)
# INFO:test:Gave node n2 a configured initial position: ['250', '350', '300']
# 0.00     WARNING test.aietes.Node[n2].Layercake.CSMA4FBR:I think I have pending data from None but I got something from None (2080)
# WARNING:test.aietes.Node[n2].Layercake.CSMA4FBR:I think I have pending data from None but I got something from None
# 0.00     INFO   test:Gave node n3 a configured initial position: ['250', '250', '300'] (600)
# INFO:test:Gave node n3 a configured initial position: ['250', '250', '300']
# 0.00     WARNING test.aietes.Node[n3].Layercake.CSMA4FBR:I think I have pending data from None but I got something from None (2080)
# WARNING:test.aietes.Node[n3].Layercake.CSMA4FBR:I think I have pending data from None but I got something from None
# 0.00     INFO   test:Gave node n4 a configured initial position: ['400', '270', '300'] (600)
# INFO:test:Gave node n4 a configured initial position: ['400', '270', '300']
# 0.00     WARNING test.aietes.Node[n4].Layercake.CSMA4FBR:I think I have pending data from None but I got something from None (2080)
# WARNING:test.aietes.Node[n4].Layercake.CSMA4FBR:I think I have pending data from None but I got something from None
# 0.00     INFO   test:Gave node n5 a configured initial position: ['400', '330', '300'] (600)
# INFO:test:Gave node n5 a configured initial position: ['400', '330', '300']
# 0.00     WARNING test.aietes.Node[n5].Layercake.CSMA4FBR:I think I have pending data from None but I got something from None (2080)
# WARNING:test.aietes.Node[n5].Layercake.CSMA4FBR:I think I have pending data from None but I got something from None
# 0.00     INFO   test.aietes.Fleet:creating Fleet instance with 6 nodes (52)
# INFO:test.aietes.Fleet:creating Fleet instance with 6 nodes
# 0.00     INFO   test:Initialising Simulation test, to run for 1250.0 steps (207)
# INFO:test:Initialising Simulation test, to run for 1250.0 steps
# 53.00    INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Synchronising counters: ['n1', 'n2', 'n3', 'n4', 'n5'] not in rx and ['n1', 'n2', 'n3', 'n4', 'n5'] not in tx, [] not in total (456)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Synchronising counters: ['n1', 'n2', 'n3', 'n4', 'n5'] not in rx and ['n1', 'n2', 'n3', 'n4', 'n5'] not in tx, [] not in total
# 53.00    INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Finished Stream 1 for n3, sleeping for 46 (958)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Finished Stream 1 for n3, sleeping for 46
# /home/bolster/src/aietes/src/aietes/Layercake/RoutingLayer.py:869: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if destination[0:3] == "ANY":
# 53.61    INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Packet n00 from n0 (183)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Packet n00 from n0
# 53.61    INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:App Packet received from n0 (218)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:App Packet received from n0
# 53.61    INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Synchronising counters: ['n0', 'n1', 'n2', 'n4', 'n5'] not in rx and ['n0', 'n1', 'n2', 'n4', 'n5'] not in tx, [] not in total (456)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Synchronising counters: ['n0', 'n1', 'n2', 'n4', 'n5'] not in rx and ['n0', 'n1', 'n2', 'n4', 'n5'] not in tx, [] not in total
# 53.61    INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Stream 1 from n0 after 0.609413037878 (992)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Stream 1 from n0 after 0.609413037878
# 53.67    INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Confirmed TX of n00 to n3 at 53.6653250871 after 0.665325087051 (113)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Confirmed TX of n00 to n3 at 53.6653250871 after 0.665325087051
# 54.00    INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 1 for n4, sleeping for 34 (958)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 1 for n4, sleeping for 34
# 57.00    INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Synchronising counters: ['n0', 'n1', 'n2', 'n3', 'n5'] not in rx and ['n0', 'n1', 'n2', 'n3', 'n5'] not in tx, [] not in total (456)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Synchronising counters: ['n0', 'n1', 'n2', 'n3', 'n5'] not in rx and ['n0', 'n1', 'n2', 'n3', 'n5'] not in tx, [] not in total
# 57.00    INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Finished Stream 1 for n0, sleeping for 40 (958)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Finished Stream 1 for n0, sleeping for 40
# 60.00    INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Synchronising counters: ['n0', 'n1', 'n2', 'n3', 'n4'] not in rx and ['n0', 'n1', 'n2', 'n3', 'n4'] not in tx, [] not in total (456)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Synchronising counters: ['n0', 'n1', 'n2', 'n3', 'n4'] not in rx and ['n0', 'n1', 'n2', 'n3', 'n4'] not in tx, [] not in total
# 60.00    INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Finished Stream 1 for n4, sleeping for 49 (958)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Finished Stream 1 for n4, sleeping for 49
# 61.88    INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n40 from n4 (183)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n40 from n4
# 61.88    INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n4 (218)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n4
# 61.88    INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 1 from n4 after 4.87942927188 (992)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 1 from n4 after 4.87942927188
# 61.97    INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Confirmed TX of n40 to n0 at 61.9695213149 after 4.96952131494 (113)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Confirmed TX of n40 to n0 at 61.9695213149 after 4.96952131494
# 64.60    INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Packet n30 from n3 (183)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Packet n30 from n3
# 64.60    INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:App Packet received from n3 (218)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:App Packet received from n3
# 64.60    INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Stream 1 from n3 after 10.5990991176 (992)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Stream 1 from n3 after 10.5990991176
# 64.66    INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n30 to n4 at 64.6633882671 after 10.6633882671 (113)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n30 to n4 at 64.6633882671 after 10.6633882671
# 66.00    INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Synchronising counters: ['n0', 'n1', 'n3', 'n4', 'n5'] not in rx and ['n0', 'n1', 'n3', 'n4', 'n5'] not in tx, [] not in total (456)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Synchronising counters: ['n0', 'n1', 'n3', 'n4', 'n5'] not in rx and ['n0', 'n1', 'n3', 'n4', 'n5'] not in tx, [] not in total
# 66.00    INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 1 for n0, sleeping for 46 (958)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 1 for n0, sleeping for 46
# 70.00    INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Synchronising counters: ['n0', 'n2', 'n3', 'n4', 'n5'] not in rx and ['n0', 'n2', 'n3', 'n4', 'n5'] not in tx, [] not in total (456)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Synchronising counters: ['n0', 'n2', 'n3', 'n4', 'n5'] not in rx and ['n0', 'n2', 'n3', 'n4', 'n5'] not in tx, [] not in total
# 70.00    INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Finished Stream 1 for n4, sleeping for 43 (958)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Finished Stream 1 for n4, sleeping for 43
# 70.65    INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Packet n10 from n1 (183)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Packet n10 from n1
# 70.65    INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:App Packet received from n1 (218)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:App Packet received from n1
# 70.65    INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Stream 1 from n1 after 0.650916522214 (992)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Stream 1 from n1 after 0.650916522214
# 70.72    INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Confirmed TX of n10 to n4 at 70.7208004279 after 0.720800427911 (113)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Confirmed TX of n10 to n4 at 70.7208004279 after 0.720800427911
# 80.59    INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n20 from n2 (183)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n20 from n2
# 80.59    INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n2 (218)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n2
# 80.59    INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 1 from n2 after 14.5911979215 (992)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 1 from n2 after 14.5911979215
# 80.68    INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Confirmed TX of n20 to n0 at 80.6822160791 after 14.6822160791 (113)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Confirmed TX of n20 to n0 at 80.6822160791 after 14.6822160791
# 85.94    INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Packet n50 from n5 (183)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Packet n50 from n5
# 85.94    INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:App Packet received from n5 (218)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:App Packet received from n5
# 85.94    INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Stream 1 from n5 after 25.9404201218 (992)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Stream 1 from n5 after 25.9404201218
# 86.04    INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Confirmed TX of n50 to n4 at 86.0410608348 after 26.0410608348 (113)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Confirmed TX of n50 to n4 at 86.0410608348 after 26.0410608348
# 88.00    INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 1 for n5, sleeping for 43 (958)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 1 for n5, sleeping for 43
# 91.91    INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Packet n31 from n3 (183)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Packet n31 from n3
# 91.91    INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:App Packet received from n3 (218)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:App Packet received from n3
# 91.91    INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Stream 1 from n3 after 3.90761259982 (992)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Stream 1 from n3 after 3.90761259982
# 92.07    INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n31 to n5 at 92.0717999043 after 4.07179990434 (113)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n31 to n5 at 92.0717999043 after 4.07179990434
# 97.00    INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Finished Stream 1 for n2, sleeping for 38 (958)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Finished Stream 1 for n2, sleeping for 38
# 97.69    INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n41 from n4 (183)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n41 from n4
# 97.69    INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n4 (218)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n4
# 97.69    INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 1 from n4 after 0.690806050598 (992)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 1 from n4 after 0.690806050598
# 97.77    INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Confirmed TX of n41 to n2 at 97.7739945101 after 0.773994510109 (113)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Confirmed TX of n41 to n2 at 97.7739945101 after 0.773994510109
# 99.00    INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Finished Stream 1 for n5, sleeping for 36 (958)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Finished Stream 1 for n5, sleeping for 36
# 109.00   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Finished Stream 1 for n0, sleeping for 37 (958)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Finished Stream 1 for n0, sleeping for 37
# 112.00   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 1 for n3, sleeping for 25 (958)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 1 for n3, sleeping for 25
# 113.00   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Finished Stream 1 for n2, sleeping for 46 (958)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Finished Stream 1 for n2, sleeping for 46
# 122.51   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Packet n21 from n2 (183)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Packet n21 from n2
# 122.51   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:App Packet received from n2 (218)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:App Packet received from n2
# 122.51   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Stream 1 from n2 after 10.5132551158 (992)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Stream 1 from n2 after 10.5132551158
# 122.68   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Confirmed TX of n21 to n3 at 122.680732152 after 10.6807321522 (113)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Confirmed TX of n21 to n3 at 122.680732152 after 10.6807321522
# 129.10   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n11 from n1 (183)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n11 from n1
# 129.10   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n1 (218)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n1
# 129.10   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 1 from n1 after 16.0969796091 (992)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 1 from n1 after 16.0969796091
# 129.13   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Confirmed TX of n11 to n2 at 129.133661679 after 16.1336616789 (113)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Confirmed TX of n11 to n2 at 129.133661679 after 16.1336616789
# 131.00   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 1 for n1, sleeping for 38 (958)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 1 for n1, sleeping for 38
# 135.00   INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Finished Stream 2 for n2, sleeping for 39 (958)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Finished Stream 2 for n2, sleeping for 39
# 135.00   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Finished Stream 1 for n1, sleeping for 41 (958)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Finished Stream 1 for n1, sleeping for 41
# 135.78   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n42 from n4 (183)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n42 from n4
# 135.78   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n4 (218)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n4
# 135.78   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 2 from n4 after 0.778485191942 (992)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 2 from n4 after 0.778485191942
# 135.89   INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Confirmed TX of n42 to n2 at 135.890906747 after 0.890906747181 (113)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Confirmed TX of n42 to n2 at 135.890906747 after 0.890906747181
# 137.00   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 1 for n5, sleeping for 35 (958)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 1 for n5, sleeping for 35
# 139.14   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Packet n22 from n2 (183)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Packet n22 from n2
# 139.14   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:App Packet received from n2 (218)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:App Packet received from n2
# 139.14   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Stream 1 from n2 after 2.14153912751 (992)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Stream 1 from n2 after 2.14153912751
# 139.19   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Confirmed TX of n22 to n5 at 139.191051948 after 2.19105194807 (113)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Confirmed TX of n22 to n5 at 139.191051948 after 2.19105194807
# 146.00   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Finished Stream 1 for n1, sleeping for 35 (958)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Finished Stream 1 for n1, sleeping for 35
# 148.14   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n51 from n5 (183)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n51 from n5
# 148.14   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n5 (218)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n5
# 148.14   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 1 from n5 after 39.1445134635 (992)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 1 from n5 after 39.1445134635
# 148.36   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Confirmed TX of n51 to n0 at 148.357536303 after 39.3575363034 (113)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Confirmed TX of n51 to n0 at 148.357536303 after 39.3575363034
# 153.24   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n52 from n5 (183)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n52 from n5
# 153.24   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n5 (218)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n5
# 153.24   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 1 from n5 after 7.24190927218 (992)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 1 from n5 after 7.24190927218
# 153.32   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Confirmed TX of n52 to n1 at 153.31835647 after 7.31835647048 (113)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Confirmed TX of n52 to n1 at 153.31835647 after 7.31835647048
# 159.00   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Finished Stream 1 for n3, sleeping for 43 (958)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Finished Stream 1 for n3, sleeping for 43
# 159.82   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n32 from n3 (183)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n32 from n3
# 159.82   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n3 (218)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n3
# 159.82   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 1 from n3 after 28.8178385324 (992)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 1 from n3 after 28.8178385324
# 160.05   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n32 to n1 at 160.04940599 after 29.04940599 (113)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n32 to n1 at 160.04940599 after 29.04940599
# 169.00   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 1 for n0, sleeping for 29 (958)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 1 for n0, sleeping for 29
# 169.66   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n33 from n3 (183)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n33 from n3
# 169.66   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n3 (218)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n3
# 169.66   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 1 from n3 after 0.66070722764 (992)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 1 from n3 after 0.66070722764
# 169.73   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n33 to n0 at 169.733896049 after 0.73389604863 (113)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n33 to n0 at 169.733896049 after 0.73389604863
# 172.00   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 1 for n1, sleeping for 39 (958)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 1 for n1, sleeping for 39
# 174.00   INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Finished Stream 2 for n0, sleeping for 44 (958)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Finished Stream 2 for n0, sleeping for 44
# 174.75   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n43 from n4 (183)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n43 from n4
# 174.75   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n4 (218)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n4
# 174.75   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 2 from n4 after 0.747781595155 (992)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 2 from n4 after 0.747781595155
# 174.85   INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Confirmed TX of n43 to n0 at 174.850271094 after 0.850271094143 (113)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Confirmed TX of n43 to n0 at 174.850271094 after 0.850271094143
# 176.00   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Finished Stream 1 for n2, sleeping for 58 (958)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Finished Stream 1 for n2, sleeping for 58
# 178.62   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Packet n01 from n0 (183)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Packet n01 from n0
# 178.62   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:App Packet received from n0 (218)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:App Packet received from n0
# 178.62   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Stream 1 from n0 after 79.6242719461 (992)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Stream 1 from n0 after 79.6242719461
# 178.87   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Confirmed TX of n01 to n5 at 178.865836534 after 79.8658365336 (113)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Confirmed TX of n01 to n5 at 178.865836534 after 79.8658365336
# 181.00   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Finished Stream 2 for n4, sleeping for 35 (958)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Finished Stream 2 for n4, sleeping for 35
# 181.98   INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Packet n53 from n5 (183)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Packet n53 from n5
# 181.98   INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:App Packet received from n5 (218)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:App Packet received from n5
# 181.98   INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Stream 2 from n5 after 0.976664564559 (992)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Stream 2 from n5 after 0.976664564559
# 182.15   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Confirmed TX of n53 to n4 at 182.154858366 after 1.15485836607 (113)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Confirmed TX of n53 to n4 at 182.154858366 after 1.15485836607
# 185.35   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Packet n12 from n1 (183)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Packet n12 from n1
# 185.35   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:App Packet received from n1 (218)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:App Packet received from n1
# 185.35   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Stream 1 from n1 after 26.3514784476 (992)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Stream 1 from n1 after 26.3514784476
# 185.58   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Confirmed TX of n12 to n3 at 185.577805208 after 26.5778052084 (113)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Confirmed TX of n12 to n3 at 185.577805208 after 26.5778052084
# 195.11   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n23 from n2 (183)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n23 from n2
# 195.11   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n2 (218)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n2
# 195.11   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 1 from n2 after 23.1133735573 (992)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 1 from n2 after 23.1133735573
# 195.15   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Confirmed TX of n23 to n1 at 195.148568622 after 23.148568622 (113)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Confirmed TX of n23 to n1 at 195.148568622 after 23.148568622
# 198.00   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 2 for n5, sleeping for 29 (958)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 2 for n5, sleeping for 29
# 199.10   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Packet n34 from n3 (183)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Packet n34 from n3
# 199.10   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:App Packet received from n3 (218)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:App Packet received from n3
# 199.10   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Stream 2 from n3 after 1.10135541521 (992)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Stream 2 from n3 after 1.10135541521
# 199.32   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n34 to n5 at 199.320260233 after 1.32026023335 (113)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n34 to n5 at 199.320260233 after 1.32026023335
# 202.00   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Finished Stream 1 for n0, sleeping for 42 (958)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Finished Stream 1 for n0, sleeping for 42
# 203.06   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n13 from n1 (183)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n13 from n1
# 203.06   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n1 (218)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n1
# 203.06   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 1 from n1 after 1.05967653184 (992)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 1 from n1 after 1.05967653184
# 203.27   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Confirmed TX of n13 to n0 at 203.265577723 after 1.26557772294 (113)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Confirmed TX of n13 to n0 at 203.265577723 after 1.26557772294
# 211.00   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 2 for n5, sleeping for 38 (958)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 2 for n5, sleeping for 38
# 211.71   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Packet n24 from n2 (183)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Packet n24 from n2
# 211.71   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:App Packet received from n2 (218)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:App Packet received from n2
# 211.71   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Stream 2 from n2 after 0.705790754517 (992)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Stream 2 from n2 after 0.705790754517
# 211.79   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Confirmed TX of n24 to n5 at 211.793929587 after 0.793929586525 (113)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Confirmed TX of n24 to n5 at 211.793929587 after 0.793929586525
# 216.00   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Finished Stream 2 for n1, sleeping for 40 (958)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Finished Stream 2 for n1, sleeping for 40
# 216.69   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n02 from n0 (183)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n02 from n0
# 216.69   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n0 (218)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n0
# 216.69   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 1 from n0 after 81.6932907832 (992)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 1 from n0 after 81.6932907832
# 216.90   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Confirmed TX of n02 to n1 at 216.898842525 after 81.8988425247 (113)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Confirmed TX of n02 to n1 at 216.898842525 after 81.8988425247
# 218.00   INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Finished Stream 1 for n1, sleeping for 42 (958)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Finished Stream 1 for n1, sleeping for 42
# 220.45   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n03 from n0 (183)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n03 from n0
# 220.45   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n0 (218)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n0
# 220.45   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 1 from n0 after 44.4481254844 (992)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 1 from n0 after 44.4481254844
# 220.70   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Confirmed TX of n03 to n2 at 220.695906674 after 44.6959066736 (113)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Confirmed TX of n03 to n2 at 220.695906674 after 44.6959066736
# 225.42   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n44 from n4 (183)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n44 from n4
# 225.42   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n4 (218)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n4
# 225.42   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 1 from n4 after 7.42049771399 (992)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 1 from n4 after 7.42049771399
# 225.48   INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Confirmed TX of n44 to n1 at 225.479772168 after 7.47977216806 (113)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Confirmed TX of n44 to n1 at 225.479772168 after 7.47977216806
# 227.00   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 1 for n2, sleeping for 36 (958)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 1 for n2, sleeping for 36
# 234.00   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Finished Stream 1 for n4, sleeping for 40 (958)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Finished Stream 1 for n4, sleeping for 40
# 235.03   INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Packet n04 from n0 (183)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Packet n04 from n0
# 235.03   INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:App Packet received from n0 (218)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:App Packet received from n0
# 235.03   INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Stream 1 from n0 after 1.02641529457 (992)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Stream 1 from n0 after 1.02641529457
# 235.22   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Confirmed TX of n04 to n4 at 235.223316986 after 1.22331698616 (113)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Confirmed TX of n04 to n4 at 235.223316986 after 1.22331698616
# 241.94   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n35 from n3 (183)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n35 from n3
# 241.94   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n3 (218)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n3
# 241.94   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 1 from n3 after 14.9368057898 (992)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 1 from n3 after 14.9368057898
# 242.19   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n35 to n2 at 242.192126287 after 15.1921262871 (113)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n35 to n2 at 242.192126287 after 15.1921262871
# 244.00   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Finished Stream 1 for n5, sleeping for 42 (958)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Finished Stream 1 for n5, sleeping for 42
# 249.00   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 2 for n3, sleeping for 37 (958)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 2 for n3, sleeping for 37
# 250.22   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Packet n25 from n2 (183)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Packet n25 from n2
# 250.22   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:App Packet received from n2 (218)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:App Packet received from n2
# 250.22   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Stream 2 from n2 after 1.21814696245 (992)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Stream 2 from n2 after 1.21814696245
# 250.48   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Confirmed TX of n25 to n3 at 250.477449344 after 1.47744934409 (113)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Confirmed TX of n25 to n3 at 250.477449344 after 1.47744934409
# 253.49   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Packet n14 from n1 (183)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Packet n14 from n1
# 253.49   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:App Packet received from n1 (218)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:App Packet received from n1
# 253.49   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Stream 1 from n1 after 9.49439618135 (992)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Stream 1 from n1 after 9.49439618135
# 253.59   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Confirmed TX of n14 to n5 at 253.585705203 after 9.58570520344 (113)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Confirmed TX of n14 to n5 at 253.585705203 after 9.58570520344
# 256.00   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Finished Stream 1 for n2, sleeping for 37 (958)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Finished Stream 1 for n2, sleeping for 37
# 256.72   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n54 from n5 (183)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n54 from n5
# 256.72   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n5 (218)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n5
# 256.72   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 2 from n5 after 40.7175069141 (992)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 2 from n5 after 40.7175069141
# 256.81   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Confirmed TX of n54 to n1 at 256.809462064 after 40.8094620639 (113)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Confirmed TX of n54 to n1 at 256.809462064 after 40.8094620639
# 260.00   INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Finished Stream 1 for n3, sleeping for 32 (958)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Finished Stream 1 for n3, sleeping for 32
# 261.23   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Packet n45 from n4 (183)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Packet n45 from n4
# 261.23   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:App Packet received from n4 (218)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:App Packet received from n4
# 261.23   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Stream 1 from n4 after 1.22633284128 (992)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Stream 1 from n4 after 1.22633284128
# 261.49   INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Confirmed TX of n45 to n3 at 261.488518769 after 1.48851876944 (113)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Confirmed TX of n45 to n3 at 261.488518769 after 1.48851876944
# 263.00   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 2 for n0, sleeping for 39 (958)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 2 for n0, sleeping for 39
# 265.35   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n36 from n3 (183)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n36 from n3
# 265.35   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n3 (218)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n3
# 265.35   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 2 from n3 after 2.34779916821 (992)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 2 from n3 after 2.34779916821
# 265.52   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n36 to n0 at 265.515703793 after 2.51570379326 (113)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n36 to n0 at 265.515703793 after 2.51570379326
# 272.38   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n55 from n5 (183)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n55 from n5
# 272.38   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n5 (218)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n5
# 272.38   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 1 from n5 after 16.383884009 (992)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 1 from n5 after 16.383884009
# 272.52   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Confirmed TX of n55 to n2 at 272.522810502 after 16.5228105017 (113)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Confirmed TX of n55 to n2 at 272.522810502 after 16.5228105017
# 274.00   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Finished Stream 2 for n5, sleeping for 29 (958)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Finished Stream 2 for n5, sleeping for 29
# 278.11   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Packet n05 from n0 (183)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Packet n05 from n0
# 278.11   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:App Packet received from n0 (218)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:App Packet received from n0
# 278.11   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Stream 2 from n0 after 4.10811327705 (992)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Stream 2 from n0 after 4.10811327705
# 278.37   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Confirmed TX of n05 to n5 at 278.369672219 after 4.36967221938 (113)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Confirmed TX of n05 to n5 at 278.369672219 after 4.36967221938
# 286.00   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Finished Stream 2 for n0, sleeping for 47 (958)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Finished Stream 2 for n0, sleeping for 47
# 286.00   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 2 for n0, sleeping for 35 (958)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 2 for n0, sleeping for 35
# 287.02   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n15 from n1 (183)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n15 from n1
# 287.02   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n1 (218)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n1
# 287.02   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 2 from n1 after 1.01826627484 (992)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 2 from n1 after 1.01826627484
# 287.21   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Confirmed TX of n15 to n0 at 287.208942986 after 1.20894298616 (113)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Confirmed TX of n15 to n0 at 287.208942986 after 1.20894298616
# 292.00   INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Finished Stream 3 for n2, sleeping for 43 (958)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Finished Stream 3 for n2, sleeping for 43
# 292.46   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n46 from n4 (183)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n46 from n4
# 292.46   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n4 (218)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n4
# 292.46   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 3 from n4 after 0.462032307102 (992)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 3 from n4 after 0.462032307102
# 292.47   INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Confirmed TX of n46 to n2 at 292.468905273 after 0.468905273453 (113)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Confirmed TX of n46 to n2 at 292.468905273 after 0.468905273453
# 293.00   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Finished Stream 3 for n4, sleeping for 44 (958)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Finished Stream 3 for n4, sleeping for 44
# 302.00   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 2 for n1, sleeping for 35 (958)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 2 for n1, sleeping for 35
# 302.80   INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Packet n56 from n5 (183)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Packet n56 from n5
# 302.80   INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:App Packet received from n5 (218)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:App Packet received from n5
# 302.80   INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Stream 3 from n5 after 9.79582489045 (992)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Stream 3 from n5 after 9.79582489045
# 302.97   INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Confirmed TX of n56 to n4 at 302.972126576 after 9.97212657573 (113)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Confirmed TX of n56 to n4 at 302.972126576 after 9.97212657573
# 303.00   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Finished Stream 2 for n2, sleeping for 46 (958)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Finished Stream 2 for n2, sleeping for 46
# 309.97   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n06 from n0 (183)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n06 from n0
# 309.97   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n0 (218)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n0
# 309.97   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 2 from n0 after 6.97288081631 (992)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 2 from n0 after 6.97288081631
# 310.22   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Confirmed TX of n06 to n2 at 310.221918268 after 7.22191826833 (113)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Confirmed TX of n06 to n2 at 310.221918268 after 7.22191826833
# 316.60   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n37 from n3 (183)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n37 from n3
# 316.60   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n3 (218)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n3
# 316.60   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 2 from n3 after 14.5971744086 (992)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 2 from n3 after 14.5971744086
# 316.75   INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n37 to n1 at 316.752597993 after 14.7525979932 (113)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n37 to n1 at 316.752597993 after 14.7525979932
# 321.00   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 2 for n1, sleeping for 39 (958)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 2 for n1, sleeping for 39
# 322.17   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n26 from n2 (183)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n26 from n2
# 322.17   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n2 (218)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n2
# 322.17   INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 2 from n2 after 36.1696027204 (992)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 2 from n2 after 36.1696027204
# 322.41   INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Confirmed TX of n26 to n0 at 322.411441036 after 36.411441036 (113)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Confirmed TX of n26 to n0 at 322.411441036 after 36.411441036
# 326.32   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n27 from n2 (183)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n27 from n2
# 326.32   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n2 (218)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n2
# 326.32   INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 2 from n2 after 5.32388804292 (992)
# ...
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 7 for n4, sleeping for 47
# 1153.10  INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Packet n329 from n3 (183)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Packet n329 from n3
# 1153.10  INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:App Packet received from n3 (218)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:App Packet received from n3
# 1153.10  INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Stream 7 from n3 after 2.10055232954 (992)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Stream 7 from n3 after 2.10055232954
# 1153.14  INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n329 to n4 at 1153.13502109 after 2.13502108603 (113)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n329 to n4 at 1153.13502109 after 2.13502108603
# 1159.00  INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n127 from n1 (183)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n127 from n1
# 1159.00  INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n1 (218)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n1
# 1159.00  INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 5 from n1 after 14.0041368279 (992)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 5 from n1 after 14.0041368279
# 1159.12  INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Confirmed TX of n127 to n2 at 1159.12065726 after 14.120657261 (113)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Confirmed TX of n127 to n2 at 1159.12065726 after 14.120657261
# 1163.00  INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Finished Stream 9 for n4, sleeping for 33 (958)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Finished Stream 9 for n4, sleeping for 33
# 1164.00  INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 8 for n0, sleeping for 45 (958)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 8 for n0, sleeping for 45
# 1164.16  INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Packet n527 from n5 (183)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Packet n527 from n5
# 1164.16  INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:App Packet received from n5 (218)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:App Packet received from n5
# 1164.16  INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Stream 9 from n5 after 1.1618947293 (992)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Got Stream 9 from n5 after 1.1618947293
# 1164.40  INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Confirmed TX of n527 to n4 at 1164.4021852 after 1.40218519868 (113)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Confirmed TX of n527 to n4 at 1164.4021852 after 1.40218519868
# 1170.00  INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Finished Stream 7 for n1, sleeping for 38 (958)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Finished Stream 7 for n1, sleeping for 38
# 1170.88  INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n428 from n4 (183)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n428 from n4
# 1170.88  INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n4 (218)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n4
# 1170.88  INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 7 from n4 after 0.884479145955 (992)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 7 from n4 after 0.884479145955
# 1171.03  INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Confirmed TX of n428 to n1 at 1171.03218584 after 1.03218584385 (113)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Confirmed TX of n428 to n1 at 1171.03218584 after 1.03218584385
# 1173.00  INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Finished Stream 8 for n3, sleeping for 39 (958)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Finished Stream 8 for n3, sleeping for 39
# 1177.38  INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Packet n028 from n0 (183)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Packet n028 from n0
# 1177.38  INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:App Packet received from n0 (218)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:App Packet received from n0
# 1177.38  INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Stream 8 from n0 after 4.37882366044 (992)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Stream 8 from n0 after 4.37882366044
# 1177.60  INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Confirmed TX of n028 to n3 at 1177.60402603 after 4.60402602788 (113)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Confirmed TX of n028 to n3 at 1177.60402603 after 4.60402602788
# 1181.50  INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n229 from n2 (183)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n229 from n2
# 1181.50  INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n2 (218)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n2
# 1181.50  INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 8 from n2 after 17.4970554336 (992)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 8 from n2 after 17.4970554336
# 1181.70  INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Confirmed TX of n229 to n0 at 1181.70321868 after 17.7032186809 (113)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Confirmed TX of n229 to n0 at 1181.70321868 after 17.7032186809
# 1191.00  INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Finished Stream 7 for n0, sleeping for 37 (958)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Finished Stream 7 for n0, sleeping for 37
# 1191.64  INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n128 from n1 (183)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Packet n128 from n1
# 1191.64  INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n1 (218)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:App Packet received from n1
# 1191.64  INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 7 from n1 after 0.640064378481 (992)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Got Stream 7 from n1 after 0.640064378481
# 1191.71  INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Confirmed TX of n128 to n0 at 1191.70579184 after 0.705791839743 (113)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Confirmed TX of n128 to n0 at 1191.70579184 after 0.705791839743
# 1196.00  INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Finished Stream 6 for n2, sleeping for 33 (958)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Finished Stream 6 for n2, sleeping for 33
# 1197.13  INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n528 from n5 (183)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n528 from n5
# 1197.13  INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n5 (218)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n5
# 1197.13  INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 6 from n5 after 1.13035553453 (992)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 6 from n5 after 1.13035553453
# 1197.36  INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Confirmed TX of n528 to n2 at 1197.36038751 after 1.3603875101 (113)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Confirmed TX of n528 to n2 at 1197.36038751 after 1.3603875101
# 1198.00  INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 9 for n1, sleeping for 37 (958)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 9 for n1, sleeping for 37
# 1208.00  INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Finished Stream 8 for n2, sleeping for 39 (958)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Finished Stream 8 for n2, sleeping for 39
# 1208.55  INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n330 from n3 (183)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n330 from n3
# 1208.55  INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n3 (218)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n3
# 1208.55  INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 9 from n3 after 10.5533955737 (992)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 9 from n3 after 10.5533955737
# 1208.70  INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n330 to n1 at 1208.69831124 after 10.6983112441 (113)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n330 to n1 at 1208.69831124 after 10.6983112441
# 1209.00  INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 6 for n3, sleeping for 35 (958)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 6 for n3, sleeping for 35
# 1212.00  INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Finished Stream 6 for n1, sleeping for 40 (958)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Finished Stream 6 for n1, sleeping for 40
# 1212.58  INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n029 from n0 (183)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Packet n029 from n0
# 1212.58  INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n0 (218)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:App Packet received from n0
# 1212.58  INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 6 from n0 after 0.577372382884 (992)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Got Stream 6 from n0 after 0.577372382884
# 1212.62  INFO   test.aietes.Node[n0].App:CommsTrustRoundRobin:Confirmed TX of n029 to n1 at 1212.62221122 after 0.622211217948 (113)
# INFO:test.aietes.Node[n0].App:CommsTrustRoundRobin:Confirmed TX of n029 to n1 at 1212.62221122 after 0.622211217948
# 1221.49  INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n429 from n4 (183)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n429 from n4
# 1221.49  INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n4 (218)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n4
# 1221.49  INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 8 from n4 after 13.4871726192 (992)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 8 from n4 after 13.4871726192
# 1221.54  INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Confirmed TX of n429 to n2 at 1221.53625176 after 13.5362517617 (113)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Confirmed TX of n429 to n2 at 1221.53625176 after 13.5362517617
# 1228.00  INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Finished Stream 4 for n3, sleeping for 41 (958)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Finished Stream 4 for n3, sleeping for 41
# 1228.87  INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Packet n129 from n1 (183)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Packet n129 from n1
# 1228.87  INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:App Packet received from n1 (218)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:App Packet received from n1
# 1228.87  INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Stream 4 from n1 after 0.866280252562 (992)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Stream 4 from n1 after 0.866280252562
# 1229.00  INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Finished Stream 7 for n3, sleeping for 36 (958)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Finished Stream 7 for n3, sleeping for 36
# 1229.01  INFO   test.aietes.Node[n1].App:CommsTrustRoundRobin:Confirmed TX of n129 to n3 at 1229.00765646 after 1.00765645886 (113)
# INFO:test.aietes.Node[n1].App:CommsTrustRoundRobin:Confirmed TX of n129 to n3 at 1229.00765646 after 1.00765645886
# 1233.07  INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Packet n230 from n2 (183)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Packet n230 from n2
# 1233.07  INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:App Packet received from n2 (218)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:App Packet received from n2
# 1233.07  INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Stream 6 from n2 after 24.0686248568 (992)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Got Stream 6 from n2 after 24.0686248568
# 1233.14  INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Confirmed TX of n230 to n3 at 1233.14158299 after 24.1415829887 (113)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Confirmed TX of n230 to n3 at 1233.14158299 after 24.1415829887
# 1235.00  INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 6 for n5, sleeping for 50 (958)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Finished Stream 6 for n5, sleeping for 50
# 1237.79  INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Packet n331 from n3 (183)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Packet n331 from n3
# 1237.79  INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:App Packet received from n3 (218)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:App Packet received from n3
# 1237.79  INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Stream 6 from n3 after 2.7862136923 (992)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Stream 6 from n3 after 2.7862136923
# 1238.08  INFO   test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n331 to n5 at 1238.08239015 after 3.08239015233 (113)
# INFO:test.aietes.Node[n3].App:CommsTrustRoundRobin:Confirmed TX of n331 to n5 at 1238.08239015 after 3.08239015233
# 1244.00  INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 7 for n5, sleeping for 35 (958)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Finished Stream 7 for n5, sleeping for 35
# 1245.10  INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Packet n231 from n2 (183)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Packet n231 from n2
# 1245.10  INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:App Packet received from n2 (218)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:App Packet received from n2
# 1245.10  INFO   test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Stream 7 from n2 after 1.10406756353 (992)
# INFO:test.aietes.Node[n5].App:CommsTrustRoundRobin:Got Stream 7 from n2 after 1.10406756353
# 1245.32  INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Confirmed TX of n231 to n5 at 1245.3236302 after 1.32363020445 (113)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Confirmed TX of n231 to n5 at 1245.3236302 after 1.32363020445
# 1247.00  INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Finished Stream 9 for n2, sleeping for 43 (958)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Finished Stream 9 for n2, sleeping for 43
# 1249.13  INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n430 from n4 (183)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Packet n430 from n4
# 1249.13  INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n4 (218)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:App Packet received from n4
# 1249.13  INFO   test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 9 from n4 after 2.13155500639 (992)
# INFO:test.aietes.Node[n2].App:CommsTrustRoundRobin:Got Stream 9 from n4 after 2.13155500639
# 1249.22  INFO   test.aietes.Node[n4].App:CommsTrustRoundRobin:Confirmed TX of n430 to n2 at 1249.21673197 after 2.21673196684 (113)
# INFO:test.aietes.Node[n4].App:CommsTrustRoundRobin:Confirmed TX of n430 to n2 at 1249.21673197 after 2.21673196684
# 1250.00  INFO   test:Finished Simulation at 1250.0(20 minutes 50.0 seconds) after 10.3832449913 seconds (218)
# INFO:test:Finished Simulation at 1250.0(20 minutes 50.0 seconds) after 10.3832449913 seconds

# %%
_ = np.seterr(invalid='ignore') # Pandas PITA Nan printing
df=dp.get_global_trust_logs().swaplevel('t','target')

# %%
dp.plot_axes_views()

# %%
f, (ax1, ax2) = plt.subplots(2, 1)

ax1.plot(np.linalg.norm(dp.p, axis=1).T)
ax2.plot(np.linalg.norm(np.diff(dp.p), axis=1).T)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1af03343b22f> in <module>()
# ----> 1 f, (ax1, ax2) = plt.subplots(2, 1)
#       2
#       3 ax1.plot(np.linalg.norm(dp.p, axis=1).T)
#       4 ax2.plot(np.linalg.norm(np.diff(dp.p), axis=1).T)
#
# NameError: name 'plt' is not defined

# %%
avg_vec = np.average(np.diff(dp.p), axis=0)
plot(np.linalg.norm(avg_vec - np.diff(dp.p), axis=1).T)
avg_vec.shape == (3,1249)

# %%
from scipy.spatial.distance import pdist, squareform
sqdist = lambda pt: squareform(pdist(pt))
indd = np.average(np.asarray([sqdist(_pt) for _pt in np.rollaxis(dp.p,2)]), axis=1).T

indd[1].shape

# %%
_p = np.diff(dp.p)
res=120
f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
f.suptitle("Node Layout and mobility for")
for n, node_p in enumerate(_p):
    x, y, z = node_p[:, 0]

    ax1.scatter(x, y)
    ax2.scatter(y, z)
    ax3.scatter(x, z)

    xs = node_p[0, ::res]
    ys = node_p[1, ::res]
    zs = node_p[2, ::res]
    ax1.plot(xs, ys, alpha=0.6)
    ax2.plot(ys, zs, alpha=0.6)
    ax3.plot(xs, zs, alpha=0.6)
    ax4.plot(
        np.abs(np.linalg.norm(node_p[:, :], axis=0) - np.linalg.norm(node_p[:, 0])),
        alpha=0.6
    )

ax1.set_title("X-Y (Top)")
ax1.set_aspect('equal', adjustable='datalim')
ax2.set_title("Y-Z (Side)")
ax2.set_aspect('equal', adjustable='datalim')
ax3.set_title("X-Z (Front)")
ax3.set_aspect('equal', adjustable='datalim')
ax4.set_title("Distance from initial position (m)")
ax4.legend(loc='upper center', ncol=3)

# %%
dff=pd.concat([df], keys= [0]+df.index.names, names = ['run']+df.index.names)
df=pd.concat([dff], keys= [0]+dff.index.names, names = ['var']+dff.index.names)

df

# %%
tp=Trust.generate_node_trust_perspective(df)
tp_net=Trust.network_trust_dict(tp)
sns.boxplot(tp_net.dropna())
plt.ylim((0.0,1.0))
plt.show()

# %%
df.index

# %%
df.index.levels.index(df.index.names)

# %%
df.index.names.index('t')
